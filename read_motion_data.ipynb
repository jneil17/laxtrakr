# %%
import pandas as pd
import os 
import sys
import csv
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
import matplotlib as mpl
import numpy as np
import plotly.graph_objects as go
import math 
import dash
from dash.dependencies import Input, Output, State
import dash_core_components as dcc
import dash_html_components as html
import dash_table_experiments as dt
import json
import pandas as pd
import numpy as np
import plotly
import os
import csv
import plotly.tools as tls
import plotly.graph_objs

import matplotlib.pyplot as plt
import seaborn as sns

# %%
pip install chart-studio
# Out:
# Collecting chart-studio
#   Downloading chart_studio-1.1.0-py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 3.7 MB/s  eta 0:00:01
# Requirement already satisfied: six in /home/jneil/miniconda3/lib/python3.9/site-packages (from chart-studio) (1.16.0)
# Requirement already satisfied: requests in /home/jneil/miniconda3/lib/python3.9/site-packages (from chart-studio) (2.25.1)
# Collecting retrying>=1.3.3
#   Downloading retrying-1.3.3.tar.gz (10 kB)
# Requirement already satisfied: plotly in /home/jneil/miniconda3/lib/python3.9/site-packages (from chart-studio) (5.8.0)
# Requirement already satisfied: tenacity>=6.2.0 in /home/jneil/miniconda3/lib/python3.9/site-packages (from plotly->chart-studio) (8.0.1)
# Requirement already satisfied: idna<3,>=2.5 in /home/jneil/miniconda3/lib/python3.9/site-packages (from requests->chart-studio) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/jneil/miniconda3/lib/python3.9/site-packages (from requests->chart-studio) (1.26.6)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jneil/miniconda3/lib/python3.9/site-packages (from requests->chart-studio) (2021.5.30)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/jneil/miniconda3/lib/python3.9/site-packages (from requests->chart-studio) (4.0.0)
# Building wheels for collected packages: retrying
#   Building wheel for retrying (setup.py) ... done
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11429 sha256=987e560782211569053f3b3b8d2c1dd263aeaf4a8ff55bce472ca9b9436d8a6f
#   Stored in directory: /home/jneil/.cache/pip/wheels/ce/18/7f/e9527e3e66db1456194ac7f61eb3211068c409edceecff2d31
# Successfully built retrying
# Installing collected packages: retrying, chart-studio
# Successfully installed chart-studio-1.1.0 retrying-1.3.3
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.11.2-py3-none-any.whl (292 kB)
#      |████████████████████████████████| 292 kB 15.8 MB/s eta 0:00:01
# Requirement already satisfied: matplotlib>=2.2 in /home/jneil/miniconda3/lib/python3.9/site-packages (from seaborn) (3.4.3)
# Collecting scipy>=1.0
#   Downloading scipy-1.8.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.2 MB)
#      |████████████████████████████████| 42.2 MB 42.7 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.15 in /home/jneil/miniconda3/lib/python3.9/site-packages (from seaborn) (1.21.3)
# Requirement already satisfied: pandas>=0.23 in /home/jneil/miniconda3/lib/python3.9/site-packages (from seaborn) (1.3.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/jneil/miniconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/jneil/miniconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/jneil/miniconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (2.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /home/jneil/miniconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/jneil/miniconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: six in /home/jneil/miniconda3/lib/python3.9/site-packages (from cycler>=0.10->matplotlib>=2.2->seaborn) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in /home/jneil/miniconda3/lib/python3.9/site-packages (from pandas>=0.23->seaborn) (2021.3)
# Installing collected packages: scipy, seaborn
# Successfully installed scipy-1.8.1 seaborn-0.11.2
# Note: you may need to restart the kernel to use updated packages.

# %%
cwd = os.getcwd()
df = pd.read_csv('/mnt/c/Users/john.neil/Documents/Side Projects/LaxTrakr/Hz25_G2_Cali1.csv') #the issue with thsi is always the /mnt/c/
print (df)
# Out:
#          epoc (ms)        timestamp (-0400)  elapsed (s)  x-axis (g)  \
# 0    1654190032394  2022-06-02T13.13.52.394        0.000       0.030
# 1    1654190032433  2022-06-02T13.13.52.433        0.039       0.031
# 2    1654190032474  2022-06-02T13.13.52.474        0.080       0.030
# 3    1654190032514  2022-06-02T13.13.52.514        0.120       0.030
# 4    1654190032553  2022-06-02T13.13.52.553        0.159       0.031
# ..             ...                      ...          ...         ...
# 537  1654190053890  2022-06-02T13.14.13.890       21.496       0.033
# 538  1654190053930  2022-06-02T13.14.13.930       21.536       0.034
# 539  1654190053971  2022-06-02T13.14.13.971       21.577       0.033
# 540  1654190054010  2022-06-02T13.14.14.010       21.616       0.033
# 541  1654190054050  2022-06-02T13.14.14.050       21.656       0.034
#
#      y-axis (g)  z-axis (g)
# 0         0.023       0.972
# 1         0.023       0.981
# 2         0.023       0.978
# 3         0.023       0.978
# 4         0.024       0.978
# ..          ...         ...
# 537       0.009       0.980
# 538       0.008       0.979
# 539       0.009       0.978
# 540       0.008       0.978
# 541       0.008       0.979
#
# [542 rows x 6 columns]

# %%
csvData = np.array(df[["x-axis (g)", "y-axis (g)","z-axis (g)"]])

# %%
csvData
# Out:
# array([[0.03 , 0.023, 0.972],
#        [0.031, 0.023, 0.981],
#        [0.03 , 0.023, 0.978],
#        ...,
#        [0.033, 0.009, 0.978],
#        [0.033, 0.008, 0.978],
#        [0.034, 0.008, 0.979]])

# %%
csvData = csvData.astype(np.float)
# Out:
# /tmp/ipykernel_4787/4256442929.py:1: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   csvData = csvData.astype(np.float)

# %%
X, Y, Z = csvData[:,0], csvData[:,1], csvData[:,2]

# %%
import os

print(os.path.basename("usr/temp/eng"))
# Out:
# eng

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_trisurf(X, Y, Z, color='white', edgecolors='grey', alpha=0.7)
ax.scatter(X, Y, Z, c='red')
plt.show()

# %%
df_sub = df[["x-axis (g)", "y-axis (g)","z-axis (g)","elapsed (s)"]]

# %%
df_clean=df_sub.rename(columns={'x-axis (g)': 'x_axis', 'y-axis (g)': 'y_axis','z-axis (g)': 'z_axis','elapsed (s)': 'time_passed'})
print(df_clean)
# Out:
#      x_axis  y_axis  z_axis  time_passed
# 0     0.030   0.023   0.972        0.000
# 1     0.031   0.023   0.981        0.039
# 2     0.030   0.023   0.978        0.080
# 3     0.030   0.023   0.978        0.120
# 4     0.031   0.024   0.978        0.159
# ..      ...     ...     ...          ...
# 537   0.033   0.009   0.980       21.496
# 538   0.034   0.008   0.979       21.536
# 539   0.033   0.009   0.978       21.577
# 540   0.033   0.008   0.978       21.616
# 541   0.034   0.008   0.979       21.656
#
# [542 rows x 4 columns]

# %%
plt.rcParams["figure.figsize"] = (20,10)
#df_clean[["x_axis", "y_axis","z_axis"]].plot()
#df_clean[["x_axis", "y_axis"]].plot()
df_clean[["z_axis"]].plot()
#pyplot.show()
# Out:
# <AxesSubplot:>

# %%
df = pd.read_csv('/mnt/c/Users/john.neil/Documents/Side Projects/LaxTrakr/yani_data.csv') #the issue with thsi is always the /mnt/c/
df_sub = df[["x-axis (g)", "y-axis (g)","z-axis (g)","elapsed (s)"]]
df_clean=df_sub.rename(columns={'x-axis (g)': 'x_axis', 'y-axis (g)': 'y_axis','z-axis (g)': 'z_axis','elapsed (s)': 'time_passed'})
plt.rcParams["figure.figsize"] = (20,10)
#df_clean[["x_axis", "y_axis","z_axis"]].plot()
#df_clean[["x_axis", "y_axis"]].plot()
df_clean[["z_axis"]].plot()
#pyplot.show()
# Out:
# <AxesSubplot:>

# %%
plot1=df_clean[["z_axis"]].plot()

# %%
fig = plot1.gcf()
plotly_fig = tls.mpl_to_plotly(fig)
py.iplot(plotly_fig)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_4787/4130984571.py in <module>
# ----> 1 fig = plot1.gcf()
#       2 plotly_fig = tls.mpl_to_plotly(fig)
#       3 py.iplot(plotly_fig)
#
# AttributeError: 'AxesSubplot' object has no attribute 'gcf'

# %%
x = np.arange(0, math.pi*2, 0.05)
y = np.sin(x)
plt.plot(x,y)
plt.xlabel("angle")
plt.ylabel("sine")
plt.title('sine wave')
plt.show()

# %%
fig = plt.gcf()
plotly_fig = tls.mpl_to_plotly(fig)
#py.iplot(plotly_fig)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_4787/1832464177.py in <module>
#       1 fig = plt.gcf()
# ----> 2 plotly_fig = tls.mpl_to_plotly(fig)
#       3 #py.iplot(plotly_fig)
#
# ~/miniconda3/lib/python3.9/site-packages/plotly/tools.py in mpl_to_plotly(fig, resize, strip_style, verbose)
#     109     if matplotlylib:
#     110         renderer = matplotlylib.PlotlyRenderer()
# --> 111         matplotlylib.Exporter(renderer).run(fig)
#     112         if resize:
#     113             renderer.resize()
#
# ~/miniconda3/lib/python3.9/site-packages/plotly/matplotlylib/mplexporter/exporter.py in run(self, fig)
#      51
#      52             plt.close(fig)
# ---> 53         self.crawl_fig(fig)
#      54
#      55     @staticmethod
#
# ~/miniconda3/lib/python3.9/site-packages/plotly/matplotlylib/mplexporter/exporter.py in crawl_fig(self, fig)
#     120     def crawl_fig(self, fig):
#     121         """Crawl the figure and process all axes"""
# --> 122         with self.renderer.draw_figure(fig=fig, props=utils.get_figure_properties(fig)):
#     123             for ax in fig.axes:
#     124                 self.crawl_ax(ax)
#
# ~/miniconda3/lib/python3.9/contextlib.py in __enter__(self)
#     115         del self.args, self.kwds, self.func
#     116         try:
# --> 117             return next(self.gen)
#     118         except StopIteration:
#     119             raise RuntimeError("generator didn't yield") from None
#
# ~/miniconda3/lib/python3.9/site-packages/plotly/matplotlylib/mplexporter/renderers/base.py in draw_figure(self, fig, props)
#      43         self._current_fig = fig
#      44         self._fig_props = props
# ---> 45         self.open_figure(fig=fig, props=props)
#      46         yield
#      47         self.close_figure(fig=fig)
#
# ~/miniconda3/lib/python3.9/site-packages/plotly/matplotlylib/renderer.py in open_figure(self, fig, props)
#      87             hovermode="closest",
#      88         )
# ---> 89         self.mpl_x_bounds, self.mpl_y_bounds = mpltools.get_axes_bounds(fig)
#      90         margin = go.layout.Margin(
#      91             l=int(self.mpl_x_bounds[0] * self.plotly_fig["layout"]["width"]),
#
# ~/miniconda3/lib/python3.9/site-packages/plotly/matplotlylib/mpltools.py in get_axes_bounds(fig)
#     263         y_min.append(bounds[1])
#     264         y_max.append(bounds[1] + bounds[3])
# --> 265     x_min, y_min, x_max, y_max = min(x_min), min(y_min), max(x_max), max(y_max)
#     266     return (x_min, x_max), (y_min, y_max)
#     267
#
# ValueError: min() arg is an empty sequence

# %%
from matplotlib import pyplot as plt
import numpy as np
import math 
import chart_studio.plotly as py
#needed for definition of pi
x = np.arange(0, math.pi*2, 0.05)
y = np.sin(x)
plt.plot(x,y)
plt.xlabel("angle")
plt.ylabel("sine")
plt.title('sine wave')

fig = plt.gcf()
plotly_fig = tls.mpl_to_plotly(fig)
py.iplot(plotly_fig)
# Out:
# ---------------------------------------------------------------------------
# PlotlyRequestError                        Traceback (most recent call last)
# /tmp/ipykernel_8616/3148683123.py in <module>
#      13 fig = plt.gcf()
#      14 plotly_fig = tls.mpl_to_plotly(fig)
# ---> 15 py.iplot(plotly_fig)
#
# ~/miniconda3/lib/python3.9/site-packages/chart_studio/plotly/plotly.py in iplot(figure_or_data, **plot_options)
#     133     if "auto_open" not in plot_options:
#     134         plot_options["auto_open"] = False
# --> 135     url = plot(figure_or_data, **plot_options)
#     136
#     137     if isinstance(figure_or_data, dict):
#
# ~/miniconda3/lib/python3.9/site-packages/chart_studio/plotly/plotly.py in plot(figure_or_data, validate, **plot_options)
#     274             grid_filename = filename + "_grid"
#     275
# --> 276         grid_ops.upload(
#     277             grid=grid,
#     278             filename=grid_filename,
#
# ~/miniconda3/lib/python3.9/site-packages/chart_studio/plotly/plotly.py in upload(cls, grid, filename, world_readable, auto_open, meta)
#    1085                 payload["parent_path"] = parent_path
#    1086
# -> 1087         file_info = _create_or_overwrite_grid(payload)
#    1088
#    1089         cols = file_info["cols"]
#
# ~/miniconda3/lib/python3.9/site-packages/chart_studio/plotly/plotly.py in _create_or_overwrite_grid(data, max_retries)
#    1548     # Create file
#    1549     try:
# -> 1550         res = api_module.create(data)
#    1551     except exceptions.PlotlyRequestError as e:
#    1552         if max_retries > 0 and "already exists" in e.message:
#
# ~/miniconda3/lib/python3.9/site-packages/chart_studio/api/v2/grids.py in create(body)
#      16     """
#      17     url = build_url(RESOURCE)
# ---> 18     return request("post", url, json=body)
#      19
#      20
#
# ~/miniconda3/lib/python3.9/site-packages/retrying.py in wrapped_f(*args, **kw)
#      47             @six.wraps(f)
#      48             def wrapped_f(*args, **kw):
# ---> 49                 return Retrying(*dargs, **dkw).call(f, *args, **kw)
#      50
#      51             return wrapped_f
#
# ~/miniconda3/lib/python3.9/site-packages/retrying.py in call(self, fn, *args, **kwargs)
#     204
#     205             if not self.should_reject(attempt):
# --> 206                 return attempt.get(self._wrap_exception)
#     207
#     208             delay_since_first_attempt_ms = int(round(time.time() * 1000)) - start_time
#
# ~/miniconda3/lib/python3.9/site-packages/retrying.py in get(self, wrap_exception)
#     245                 raise RetryError(self)
#     246             else:
# --> 247                 six.reraise(self.value[0], self.value[1], self.value[2])
#     248         else:
#     249             return self.value
#
# ~/miniconda3/lib/python3.9/site-packages/six.py in reraise(tp, value, tb)
#     717             if value.__traceback__ is not tb:
#     718                 raise value.with_traceback(tb)
# --> 719             raise value
#     720         finally:
#     721             value = None
#
# ~/miniconda3/lib/python3.9/site-packages/retrying.py in call(self, fn, *args, **kwargs)
#     198         while True:
#     199             try:
# --> 200                 attempt = Attempt(fn(*args, **kwargs), attempt_number, False)
#     201             except:
#     202                 tb = sys.exc_info()
#
# ~/miniconda3/lib/python3.9/site-packages/chart_studio/api/v2/utils.py in request(method, url, **kwargs)
#     178         content = response.content if response else "No content"
#     179         raise exceptions.PlotlyRequestError(message, status_code, content)
# --> 180     validate_response(response)
#     181     return response
#
# ~/miniconda3/lib/python3.9/site-packages/chart_studio/api/v2/utils.py in validate_response(response)
#      80         message = content if content else "No Content"
#      81
# ---> 82     raise exceptions.PlotlyRequestError(message, status_code, content)
#      83
#      84
#
# PlotlyRequestError: Authentication credentials were not provided.

# %%
df = pd.read_csv('/mnt/c/Users/john.neil/Documents/Side Projects/LaxTrakr/yani_data_labled.csv') #the issue with thsi is always the /mnt/c/
df_sub = df[["x-axis (g)", "y-axis (g)","z-axis (g)","elapsed (s)","label"]]
df_clean=df_sub.rename(columns={'x-axis (g)': 'x_axis', 'y-axis (g)': 'y_axis','z-axis (g)': 'z_axis','elapsed (s)': 'time_passed','label':'label'})
plt.rcParams["figure.figsize"] = (20,10)
#df_clean[["x_axis", "y_axis","z_axis"]].plot()
#df_clean[["x_axis", "y_axis"]].plot()
df_clean[["z_axis","label"]].plot()
#pyplot.show()
# Out:
# <AxesSubplot:>

# %%
raw_data=df_clean[["time_passed","z_axis","label"]]

# %%
x = raw_data[["time_passed","z_axis"]]

# %%
y = raw_data[["label"]]

# %%
x
# Out:
#      time_passed  z_axis
# 0          0.000   0.582
# 1          0.077   0.553
# 2          0.156   0.534
# 3          0.236   0.560
# 4          0.315   0.576
# ..           ...     ...
# 980       77.191   1.075
# 981       77.269   1.042
# 982       77.348   0.955
# 983       77.427   1.036
# 984       77.506   1.028
#
# [985 rows x 2 columns]

# %%
y
# Out:
#      label
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ..     ...
# 980      0
# 981      0
# 982      0
# 983      0
# 984      0
#
# [985 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x, y, test_size = 0.3)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print(model.coef_)
# Out:
# [[ 0.00012775 -0.05066912]]

# %%
model.coef_
# Out:
# array([[ 0.00012775, -0.05066912]])

# %%
predictions = model.predict(x_test)

# %%
plt.scatter(y_test, predictions)

# %%
plt.hist(y_test - predictions)
# Out:
# (array([ 26., 254.,   0.,   0.,   0.,   6.,   2.,   1.,   0.,   7.]),
#  array([-0.21852986, -0.0807121 ,  0.05710567,  0.19492343,  0.3327412 ,
#          0.47055896,  0.60837673,  0.74619449,  0.88401225,  1.02183002,
#          1.15964778]),
#  <BarContainer object of 10 artists>)

# %%
raw_data=df_clean[["z_axis","label"]]

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3)

from sklearn.linear_model import LinearRegression

model = LinearRegression()

model.fit(x_train, y_train)

print(model.coef_)

print(model.intercept_)

##pd.DataFrame(model.coef_, x.columns, columns = ['Coeff'])

predictions = model.predict(x_test)

# plt.scatter(y_test, predictions)

plt.hist(y_test - predictions)

from sklearn import metrics

metrics.mean_absolute_error(y_test, predictions)

metrics.mean_squared_error(y_test, predictions)

np.sqrt(metrics.mean_squared_error(y_test, predictions))
# Out:
# [[ 2.32025048e-05 -5.39815906e-02]]
# [0.09699028]
# 0.19875099628353698

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math


df_clean= pd.read_csv('/mnt/c/Users/john.neil/Documents/Side Projects/LaxTrakr/yani_data.csv')

dataset =df_clean[["z_axis","label"]]

#Calculate moving average with 0.75s in both directions, then append do dataset
hrw = 0.75 #One-sided window size, as proportion of the sampling frequency
fs = 100 #The example dataset was recorded at 100Hz

mov_avg = dataset['z_axis'].rolling(int(hrw*fs)).mean() #Calculate moving average
#Impute where moving average function returns NaN, which is the beginning of the signal where x hrw
avg_hr = (np.mean(dataset.z_axis))
mov_avg = [avg_hr if math.isnan(x) else x for x in mov_avg]
mov_avg = [x*1.2 for x in mov_avg] #For now we raise the average by 20% to prevent the secondary heart contraction from interfering, in part 2 we will do this dynamically
dataset['hart_rollingmean'] = mov_avg #Append the moving average to the dataframe

#Mark regions of interest
window = []
peaklist = []
listpos = 0 #We use a counter to move over the different data columns

for datapoint in dataset.hart:
    rollingmean = dataset.hart_rollingmean[listpos] #Get local mean
    if (datapoint < rollingmean) and (len(window) < 1): #If no detectable R-complex activity -> do nothing
        listpos += 1
    elif (datapoint > rollingmean): #If signal comes above local mean, mark ROI
        window.append(datapoint)
        listpos += 1
    else: #If signal drops below local mean -> determine highest point
        maximum = max(window)
        beatposition = listpos - len(window) + (window.index(max(window))) #Notate the position of the point on the X-axis
        peaklist.append(beatposition) #Add detected peak to list
        window = [] #Clear marked ROI
        listpos += 1

ybeat = [dataset.hart[x] for x in peaklist] #Get the y-value of all peaks for plotting purposes

plt.title("Detected peaks in signal")
plt.xlim(0,2500)
plt.plot(dataset.hart, alpha=0.5, color='blue') #Plot semi-transparent HR
plt.plot(mov_avg, color ='green') #Plot moving average
plt.scatter(peaklist, ybeat, color='red') #Plot detected peaks
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_8616/786365249.py in <module>
#       7 df_clean= pd.read_csv('/mnt/c/Users/john.neil/Documents/Side Projects/LaxTrakr/yani_data.csv')
#       8
# ----> 9 dataset =df_clean[["z_axis","label"]]
#      10
#      11 #Calculate moving average with 0.75s in both directions, then append do dataset
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1372                 if use_interval_msg:
#    1373                     key = list(key)
# -> 1374                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['z_axis', 'label'], dtype='object')] are in the [columns]"

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math


df_clean= pd.read_csv('/mnt/c/Users/john.neil/Documents/Side Projects/LaxTrakr/yani_data.csv')
df_sub = df_clean[["x-axis (g)", "y-axis (g)","z-axis (g)","elapsed (s)"]]
df_clean=df_sub.rename(columns={'x-axis (g)': 'x_axis', 'y-axis (g)': 'y_axis','z-axis (g)': 'z_axis','elapsed (s)': 'time_passed'})
df_clean.z_axis=df_clean.z_axis*-1
dataset =df_clean[["z_axis","time_passed"]]

#Calculate moving average with 0.75s in both directions, then append do dataset
hrw = 0.75 #One-sided window size, as proportion of the sampling frequency
fs = 100 #The example dataset was recorded at 100Hz

# %%
dataset
# Out:
#      z_axis  time_passed
# 0    -0.582        0.000
# 1    -0.553        0.077
# 2    -0.534        0.156
# 3    -0.560        0.236
# 4    -0.576        0.315
# ..      ...          ...
# 980  -1.075       77.191
# 981  -1.042       77.269
# 982  -0.955       77.348
# 983  -1.036       77.427
# 984  -1.028       77.506
#
# [985 rows x 2 columns]

# %%
mov_avg = dataset['z_axis'].rolling(int(hrw*fs)).mean() #Calculate moving average
#Impute where moving average function returns NaN, which is the beginning of the signal where x hrw

# %%
avg_hr = (np.mean(dataset.z_axis))

# %%
mov_avg = [avg_hr if math.isnan(x) else x for x in mov_avg]

# %%
mov_avg = [x*1.2 for x in mov_avg] #For now we raise the average by 20% to prevent the secondary heart contraction from interfering, in part 2 we will do this dynamically

# %%
dataset['hart_rollingmean'] = mov_avg #Append the moving average to the dataframe
# Out:
# /tmp/ipykernel_13974/901092598.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['hart_rollingmean'] = mov_avg #Append the moving average to the dataframe

# %%
#Mark regions of interest
window = []
peaklist = []
listpos = 0 #We use a counter to move over the different data columns

for datapoint in dataset.z_axis:
    rollingmean = dataset.hart_rollingmean[listpos] #Get local mean
    if (datapoint < rollingmean) and (len(window) < 1): #If no detectable R-complex activity -> do nothing
        listpos += 1
    elif (datapoint > rollingmean): #If signal comes above local mean, mark ROI
        window.append(datapoint)
        listpos += 1
    else: #If signal drops below local mean -> determine highest point
        maximum = max(window)
        beatposition = listpos - len(window) + (window.index(max(window))) #Notate the position of the point on the X-axis
        peaklist.append(beatposition) #Add detected peak to list
        window = [] #Clear marked ROI
        listpos += 1

ybeat = [dataset.z_axis[x] for x in peaklist] #Get the y-value of all peaks for plotting purposes

plt.title("Detected peaks in signal")
plt.xlim(0,2500)
plt.plot(dataset.z_axis, alpha=0.5, color='blue') #Plot semi-transparent HR
plt.plot(mov_avg, color ='green') #Plot moving average
plt.scatter(peaklist, ybeat, color='red') #Plot detected peaks
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_15957/3005150528.py in <module>
#       4 listpos = 0 #We use a counter to move over the different data columns
#       5
# ----> 6 for datapoint in dataset.z_axis:
#       7     rollingmean = dataset.hart_rollingmean[listpos] #Get local mean
#       8     if (datapoint < rollingmean) and (len(window) < 1): #If no detectable R-complex activity -> do nothing
#
# NameError: name 'dataset' is not defined

# %%
d={'time':peaklist,'rep_peak':ybeat}
df = pd.DataFrame(d, columns=['time','rep_peak'])
print(df)
# Out:
#     time  rep_peak
# 0     45     0.216
# 1    114     0.182
# 2    123    -0.115
# 3    131    -0.707
# 4    133    -0.857
# ..   ...       ...
# 78   805    -0.645
# 79   813    -0.792
# 80   817    -0.902
# 81   822    -0.944
# 82   836    -0.792
#
# [83 rows x 2 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
plt.scatter(peaklist, ybeat, color='red')

# %%
df
# Out:
#     time  rep_peak
# 0     45     0.216
# 1    114     0.182
# 2    123    -0.115
# 3    131    -0.707
# 4    133    -0.857
# ..   ...       ...
# 78   805    -0.645
# 79   813    -0.792
# 80   817    -0.902
# 81   822    -0.944
# 82   836    -0.792
#
# [83 rows x 2 columns]

# %%
df['new_column'] = np.where(df['rep_peak']>3, 'rep')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_13974/1346393405.py in <module>
# ----> 1 df['new_column'] = np.where(df['rep_peak']>3, 'rep')
#
# <__array_function__ internals> in where(*args, **kwargs)
#
# ValueError: either both or neither of x and y should be given

# %%
df['rep_threshold'] = np.where(df['rep_peak']>3, 1, 0)

# %%
sum(df['rep_threshold'])
# Out:
# 11

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math


df_clean= pd.read_csv(r'/mnt/c/Users/john.neil/Documents/Side Projects/LaxTrakr/yani_data.csv')
df_clean=df_clean.rename(columns={'x-axis (g)': 'x_axis', 'y-axis (g)': 'y_axis','z-axis (g)': 'z_axis','elapsed (s)': 'time_passed'})
df_clean.z_axis=df_clean.z_axis*-1
dataset =df_clean[["z_axis","time_passed"]]

#Calculate moving average with 0.75s in both directions, then append do dataset
hrw = 0.75 #One-sided window size, as proportion of the sampling frequency
fs = 100 #The example dataset was recorded at 100Hz

mov_avg = dataset['z_axis'].rolling(int(hrw*fs)).mean() #Calculate moving average
#Impute where moving average function returns NaN, which is the beginning of the signal where x hrw

avg_hr = (np.mean(dataset.z_axis))

mov_avg = [avg_hr if math.isnan(x) else x for x in mov_avg]

mov_avg = [x*1.2 for x in mov_avg] #For now we raise the average by 20% to prevent the secondary heart contraction from interfering, in part 2 we will do this dynamically

dataset['hart_rollingmean'] = mov_avg #Append the moving average to the dataframe

#Mark regions of interest
window = []
peaklist = []
listpos = 0 #We use a counter to move over the different data columns

for datapoint in dataset.z_axis:
    rollingmean = dataset.hart_rollingmean[listpos] #Get local mean
    if (datapoint < rollingmean) and (len(window) < 1): #If no detectable R-complex activity -> do nothing
        listpos += 1
    elif (datapoint > rollingmean): #If signal comes above local mean, mark ROI
        window.append(datapoint)
        listpos += 1
    else: #If signal drops below local mean -> determine highest point
        maximum = max(window)
        beatposition = listpos - len(window) + (window.index(max(window))) #Notate the position of the point on the X-axis
        peaklist.append(beatposition) #Add detected peak to list
        window = [] #Clear marked ROI
        listpos += 1

ybeat = [dataset.z_axis[x] for x in peaklist] #Get the y-value of all peaks for plotting purposes

d={'time':peaklist,'rep_peak':ybeat}
df = pd.DataFrame(d, columns=['time','rep_peak'])
df['rep_threshold'] = np.where(df['rep_peak']>3, 1, 0)

sum(df['rep_threshold'])
# Out:
# /tmp/ipykernel_13974/1779111099.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['hart_rollingmean'] = mov_avg #Append the moving average to the dataframe
# 11

# %%
def laxtrakr(file_path,threshold):
    import pandas as pd
    import matplotlib.pyplot as plt
    import numpy as np
    import math
    
    cut=threshold
    df_clean= pd.read_csv(file_path)
    df_clean=df_clean.rename(columns={'x-axis (g)': 'x_axis', 'y-axis (g)': 'y_axis','z-axis (g)': 'z_axis','elapsed (s)': 'time_passed'})
    df_clean.z_axis=df_clean.z_axis*-1
    dataset =df_clean[["z_axis","time_passed"]]

    #Calculate moving average with 0.75s in both directions, then append do dataset
    hrw = 0.75 #One-sided window size, as proportion of the sampling frequency
    fs = 100 #The example dataset was recorded at 100Hz

    mov_avg = dataset['z_axis'].rolling(int(hrw*fs)).mean() #Calculate moving average
    #Impute where moving average function returns NaN, which is the beginning of the signal where x hrw

    avg_hr = (np.mean(dataset.z_axis))

    mov_avg = [avg_hr if math.isnan(x) else x for x in mov_avg]

    mov_avg = [x*1.2 for x in mov_avg] #For now we raise the average by 20% to prevent the secondary heart contraction from interfering, in part 2 we will do this dynamically

    dataset['hart_rollingmean'] = mov_avg #Append the moving average to the dataframe

    #Mark regions of interest
    window = []
    peaklist = []
    listpos = 0 #We use a counter to move over the different data columns

    for datapoint in dataset.z_axis:
        rollingmean = dataset.hart_rollingmean[listpos] #Get local mean
        if (datapoint < rollingmean) and (len(window) < 1): #If no detectable R-complex activity -> do nothing
            listpos += 1
        elif (datapoint > rollingmean): #If signal comes above local mean, mark ROI
            window.append(datapoint)
            listpos += 1
        else: #If signal drops below local mean -> determine highest point
            maximum = max(window)
            beatposition = listpos - len(window) + (window.index(max(window))) #Notate the position of the point on the X-axis
            peaklist.append(beatposition) #Add detected peak to list
            window = [] #Clear marked ROI
            listpos += 1

    ybeat = [dataset.z_axis[x] for x in peaklist] #Get the y-value of all peaks for plotting purposes

    plt.title("Detected peaks in signal")
    plt.xlim(0,max(peaklist))
    plt.plot(dataset.z_axis, alpha=0.5, color='blue') #Plot semi-transparent HR
    plt.plot(mov_avg, color ='green') #Plot moving average
    plt.scatter(peaklist, ybeat, color='red') #Plot detected peaks
    plt.rcParams["figure.figsize"] = (20,10)
    plt.axhline(y = cut, color = 'r', linestyle = '-')
    plt.show()
    
    d={'time':peaklist,'rep_peak':ybeat}
    df = pd.DataFrame(d, columns=['time','rep_peak'])
    df['rep_threshold'] = np.where(df['rep_peak']>cut, 1, 0)
    
    reps= sum(df['rep_threshold'])
    output_text = "Number of Reps: "+ str(reps) + " Threshold Number: " + str(threshold)
    
    return(output_text);

# %%
laxtrakr(r'/mnt/c/Users/john.neil/Documents/Side Projects/LaxTrakr/yani_data.csv',4.2)
# Out:
# /tmp/ipykernel_15957/3861769713.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['hart_rollingmean'] = mov_avg #Append the moving average to the dataframe
# 'Number of Reps: 11 Threshold Number: 4.2'

# %%
laxtrakr(r'/mnt/c/Users/john.neil/Documents/Side Projects/LaxTrakr/data_6_20/pitchback_jani_accelerometer.csv',4.2)
# Out:
# /tmp/ipykernel_15957/3861769713.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['hart_rollingmean'] = mov_avg #Append the moving average to the dataframe
# 'Number of Reps: 43 Threshold Number: 4.2'

# %%
def laxtrakr_x(file_path,threshold,show_plot):
    import pandas as pd
    import matplotlib.pyplot as plt
    import numpy as np
    import math
    import os
    
    cut=threshold
    df_clean= pd.read_csv(file_path)
    df_clean=df_clean.rename(columns={'x-axis (g)': 'x_axis', 'y-axis (g)': 'y_axis','z-axis (g)': 'z_axis','elapsed (s)': 'time_passed'})
    #df_clean.z_axis=df_clean.z_axis*-1
    dataset =df_clean[["x_axis","time_passed"]]

    #Calculate moving average with 0.75s in both directions, then append do dataset
    hrw = 0.75 #One-sided window size, as proportion of the sampling frequency
    fs = 100 #The example dataset was recorded at 100Hz

    mov_avg = dataset['x_axis'].rolling(int(hrw*fs)).mean() #Calculate moving average
    #Impute where moving average function returns NaN, which is the beginning of the signal where x hrw

    avg_hr = (np.mean(dataset.x_axis))

    mov_avg = [avg_hr if math.isnan(x) else x for x in mov_avg]

    mov_avg = [x*1.2 for x in mov_avg] #For now we raise the average by 20% to prevent the secondary heart contraction from interfering, in part 2 we will do this dynamically

    dataset['hart_rollingmean'] = mov_avg #Append the moving average to the dataframe

    #Mark regions of interest
    window = []
    peaklist = []
    listpos = 0 #We use a counter to move over the different data columns

    for datapoint in dataset.x_axis:
        rollingmean = dataset.hart_rollingmean[listpos] #Get local mean
        if (datapoint < rollingmean) and (len(window) < 1): #If no detectable R-complex activity -> do nothing
            listpos += 1
        elif (datapoint > rollingmean): #If signal comes above local mean, mark ROI
            window.append(datapoint)
            listpos += 1
        else: #If signal drops below local mean -> determine highest point
            maximum = max(window)
            beatposition = listpos - len(window) + (window.index(max(window))) #Notate the position of the point on the X-axis
            peaklist.append(beatposition) #Add detected peak to list
            window = [] #Clear marked ROI
            listpos += 1

    ybeat = [dataset.x_axis[x] for x in peaklist] #Get the y-value of all peaks for plotting purposes
    
    if show_plot == 'y':
        plt.title("Detected Reps"+" "+os.path.basename(file_path))
        plt.xlim(0,max(peaklist))
        plt.plot(dataset.x_axis, alpha=0.5, color='blue') #Plot semi-transparent HR
        plt.plot(mov_avg, color ='green') #Plot moving average
        plt.scatter(peaklist, ybeat, color='red') #Plot detected peaks
        plt.rcParams["figure.figsize"] = (20,10)
        plt.axhline(y = cut, color = 'r', linestyle = '-')
        plt.show()

    d={'time':peaklist,'rep_peak':ybeat}
    df = pd.DataFrame(d, columns=['time','rep_peak'])
    df['rep_threshold'] = np.where(df['rep_peak']>cut, 1, 0)
    
    reps= sum(df['rep_threshold'])
    output_text = "File Name: "+ os.path.basename(file_path) +" Number of Reps: "+ str(reps) + " Threshold Number: " + str(threshold)
    
    return(output_text);

# %%
laxtrakr_x(r'/mnt/c/Users/john.neil/Documents/Side Projects/LaxTrakr/data_6_20/RTdata4_Colin_shooting_16G.csv',4.2,'y')
# Out:
# /tmp/ipykernel_15957/3869078517.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['hart_rollingmean'] = mov_avg #Append the moving average to the dataframe
# ('File Name: RTdata4_Colin_shooting_16G.csv',
#  '\n Number of Reps: 6 Threshold Number: 4.2')

# %%
print("1. "+laxtrakr_x(r'/mnt/c/Users/john.neil/Documents/Side Projects/LaxTrakr/data_6_20/colin_update/10_reps_pitch_back_Colin_Sensor.csv',4.2,'n'))
print("2. "+laxtrakr_x(r'/mnt/c/Users/john.neil/Documents/Side Projects/LaxTrakr/data_6_20/colin_update/10_short_stroke_Colins Sensor.csv',4.2,'n'))
print("3. "+laxtrakr_x(r'/mnt/c/Users/john.neil/Documents/Side Projects/LaxTrakr/data_6_20/colin_update/10OH_10TQ_10SA_5Fk_5BxFk_Colins Sensor.csv',4.2,'y'))
print("4. "+laxtrakr_x(r'/mnt/c/Users/john.neil/Documents/Side Projects/LaxTrakr/data_6_20/colin_update/12_short_stroke_Colins_Sensor.csv',4.2,'n'))
print("5. "+laxtrakr_x(r'/mnt/c/Users/john.neil/Documents/Side Projects/LaxTrakr/data_6_20/colin_update/20_quick_stick_Colins_Sensor.csv',4.2,'n'))
print("6. "+laxtrakr_x(r'/mnt/c/Users/john.neil/Documents/Side Projects/LaxTrakr/data_6_20/colin_update/25_mixed_Colins_Sensor.csv',4.2,'n'))
print("7. "+laxtrakr_x(r'/mnt/c/Users/john.neil/Documents/Side Projects/LaxTrakr/data_6_20/colin_update/25L_25R_25Split_25Throw_split_catch_Colins_Sensor.csv',4.2,'y'))
print("8. "+laxtrakr_x(r'/mnt/c/Users/john.neil/Documents/Side Projects/LaxTrakr/data_6_20/colin_update/Random_Quicksticking_Colins_Sensor.csv',4.2,'y'))
# Out:
# /tmp/ipykernel_15957/3652596637.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['hart_rollingmean'] = mov_avg #Append the moving average to the dataframe
# 1. File Name: 10_reps_pitch_back_Colin_Sensor.csv Number of Reps: 10 Threshold Number: 4.2
# 2. File Name: 10_short_stroke_Colins Sensor.csv Number of Reps: 10 Threshold Number: 4.2
# 3. File Name: 10OH_10TQ_10SA_5Fk_5BxFk_Colins Sensor.csv Number of Reps: 34 Threshold Number: 4.2
# 4. File Name: 12_short_stroke_Colins_Sensor.csv Number of Reps: 13 Threshold Number: 4.2
# 5. File Name: 20_quick_stick_Colins_Sensor.csv Number of Reps: 20 Threshold Number: 4.2
# 6. File Name: 25_mixed_Colins_Sensor.csv Number of Reps: 25 Threshold Number: 4.2
# 7. File Name: 25L_25R_25Split_25Throw_split_catch_Colins_Sensor.csv Number of Reps: 99 Threshold Number: 4.2
# 8. File Name: Random_Quicksticking_Colins_Sensor.csv Number of Reps: 31 Threshold Number: 4.2
